# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# result_test = pd.read_csv("./result_09092019_13:40/master/master_log09092019_13:40.csv")
result_train1 = pd.read_csv("./result_09102019_15:39/worker1/worker1_log09102019_15:39.csv")
result_train2 = pd.read_csv("./result_09102019_15:39/worker2/worker2_log09102019_15:39.csv")
result_train3 = pd.read_csv("./result_09102019_15:39/worker3/worker3_log09102019_15:39.csv")

# %%
# error_test = result_test.iloc[:,1]
error_train1 = result_train1.iloc[:,1]
error_train2 = result_train2.iloc[:,1]
error_train3 = result_train3.iloc[:,1]

# %%
# error

# %%
# lKS = list(KS)
# lKS.index(max(lKS))

# %%
# train = results.train_error.values
# test = results.test_error.values

# %%
# data = pd.read_csv("./results_08302019_11:34/test/test_log08302019_11:34.csv")

# %%
# ave = data.iloc[:,0]

# %%
plt.figure(figsize=(10,10))
# plt.plot(error_test, 'b')
plt.plot(error_train1, 'r')
plt.plot(error_train2, 'y')
plt.plot(error_train3, 'g')
# plt.plot(ave, 'm')
plt.show()
